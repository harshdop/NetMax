# %%
print("hello")
# Out:
# hello

# %%
"hello"
# Out:
# 'hello'

# %%
print(chr(128513))
# Out:
# 😁

# %%
print(ord("😁"))
# Out:
# 128513

# %%
print("hello", end = " to ")
print("Chandigarh")
# Out:
# hello to Chandigarh

# %%
print(r"hel\tdlo")
# the r before the "string" is known as the reject sequence, it will make all the interpreter ignore all the backslah actions
# Out:
# hel\tdlo

# %%
x : int =12
print(x)
# Out:
# 12

# %%
x = 12;
a,b,c=1,2,3
print(x,a,b,c)
# Out:
# 12 1 2 3

# %%
x="hello"
y="world"
print(x,y)
# Out:
# hello world

# %% [markdown]
# PRINT is a pre-defined fuction to display output on screen or on the console,
# it has many parameters such as
# end = , the default action of print is to produce output and move to the next line, this can be changed by specifying the end manually,
#
# in cell 18 the out is like x(space)y, to print it as xy without any space, we have to update the sep (separeat) parameter, check cell 19

# %%
print(x,y, sep="")
# Out:
# helloworld

# %%
a = 12;
a = "hello";
print(a)
# Out:
# hello

# %% [markdown]
# above we see that python dyanimacally allocates and update the data types. below we will see how we can hard define a variable

# %%
a: int = 12;
a = "hello";
print(a)
# Out:
# hello

# %% [markdown]
# a : int = 12, is a suggestion for the develper but not a strict command;

# %%
a : int = "helo"
print(a)
# this is a suggestion but not a strict coding
# Out:
# helo

# %%
#SEE THIS OBSERVSTION;
a = 1,2,3,4,5;
print(a)
# python will automatically assign tuple to a;
print("type of a is ",type(a))
# Out:
# (1, 2, 3, 4, 5)
# type of a is  <class 'tuple'>

# %%
a : int = "hello"
print(type(a));
#another proof that a : int; does not hard code the data type
# Out:
# <class 'str'>

# %%
a = 1; # this is implicit initionilization
# Out:
# 12

# %%
a = input("Enter the value of a")
print("The value of a is", a);
# Out:
# Enter the value of a 22
# The value of a is 22
