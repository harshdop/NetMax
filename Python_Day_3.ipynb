# %% [markdown]
# #implict and explict initialization
# How to take input in python

# %%
a = input("enter your name");
print("the value user entered is", a, sep='')
# Out:
# enter your name 11
# the value user entered is11

# %%
#Taking multiple inputs
a=input("enter first name")
b= input("enter last name")
print(a,b);
# Out:
# enter first name hello my
# enter last name dear
# hello my dear

# %%
a,b = input("name")
# Out:
# name heelo, haan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a,b = input("name")
#
# ValueError: too many values to unpack (expected 2)

# %%
# How to take multiple inputs smartly,
a,b = input("enter a value and enter b value").split();
print("enter a value and b value",a,b);
#enter the values with a space, the problem only works when we enter the exact number of varibales, else it fails,
# Out:
# enter a value and enter b value 112 "hello"
# enter a value and b value 112 "hello"

# %%
a,b,c = input("enter values").split()
print("the values are", a,b,c);
# Out:
# enter values 1 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a,b,c = input("enter values").split()
#       2 print("the values are", a,b,c);
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
balance = 24.7455;
print("my balance is", balance)
# Out:
# my balance is 24.7455

# %%
bal =12;
print("the balance is" + bal)
# the + concatination in print() only works with strings, hence the error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 bal =12;
# ----> 2 print("the balance is" + bal)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("The balance is " + str(bal))
# str(a) typecasts the interger into a string, this conversion of one data type to another data type is known as typecasting
# Out:
# The balance is 12

# %%
print("hello: " + str(bal))
print(r"{bal}")
print(f"{bal}")
print(f"{balance:.3f}")
print(int(balance))
# Out:
# hello: 12
# {bal}
# 12
# 24.733
# 24

# %%
print(f"{balance:.2f}") #This is the shortcut way to round-off a, it rounds off the value not just prints upto that digit
# Out:
# 24.75

# %%
bank = "SBI"
balance = 12.334;
print(f"{balance:.2f}")

#observe the format syntax
print("your bank is {0} and balance is {1}".format(bank,balance))

#the {0} are indexes, and corresponds to the format(varibales) in the same order
# Out:
# 12.33
# your bank is SBI and balance is 12.334

# %%
a = 12.9;
print(int(a))
# see how typcasting does not rounds off the interger part
# Out:
# 12

# %%
a,b=input("Enter value of A and B").split();
print(type(a))
print(a+b);
# the default input type for variable is string, hence the result is concatenation and not sum;
# Out:
# Enter value of A and B 112 3
# <class 'str'>
# 1123

# %%
#how to avoid this,
c = int(a) + int(b);
print(c);
# Out:
# 115

# %%
#althoug we have typecast a,b to int but it is temporary;
print(type(a))
# Out:
# <class 'str'>

# %%
d = int(input("Enter d"))
e = int(input("Enter e"))
print(d+e)
# Out:
# Enter d 12
# Enter e 1
# 13

# %%
#taking multiple inputs in a single line of code with permanent typecasting
#.split() can only split string, to work with integers use map
a,b = map(int,input("Enter value for A and B").split())
print(a+b)
# Out:
# Enter value for A and B 23 3
# 26

# %%
#what split does
a= "hello my name is hello"
print(a.split())
# Out:
# ['hello', 'my', 'name', 'is', 'hello']

# %%
#the result of .split() is a list of string type entities.
