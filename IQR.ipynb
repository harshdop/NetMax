# %%
#outliers -> the extreme values in a continuous data, extreme low or extreme high values
'''
0.000001, 0.0002, 2, 3,4,5,6,9, 10, 120000, 127000
outliers                            outliers
We can identify outliers with the help of BOXPlot or ScatterPlot (reccomended ->boxplot)
we aim to remove outliers via 
IQR 
Zscore

'''

# %% [markdown]
# IQR -> ![image.png](attachment:24e5241c-ef12-4df0-969c-fa0722af98b6.png)![image.png](attachment:6aa694be-f202-463f-bd4f-26ea2b1ea3fc.png)
#
# IQR = q3 - q1
# lower whisker/ lower bound = q1 -(1.5 * IQR)
# upper whisker/ upper bound = q3 + (1.5 * IQR)

# %%
# Q1 = np.quartile(data, 25)
# Q3 = np.quartile(data, 75)
# IQR = Q3 - Q1
# calculate UB and LB
#

# %%
#how to create a data frame
#dictionay of dictonaries
import pandas as pd
dic = {
    'stu1' : {
        'Name' : "harsh",
        'Age' : 13,
      'Marks' : 89
    },
    'stu2' :{
        'Name' : "harsh",
        'Age' : 13,
      'Marks' : 89
    },
    'stu3' :{
        'Name' : "harsh",
        'Age' : 13,
      'Marks' : 89
    }
}
print(dic)
df = pd.DataFrame(dic)
df
# Out:
# {'stu1': {'Name': 'harsh', 'Age': 13, 'Marks': 89}, 'stu2': {'Name': 'harsh', 'Age': 13, 'Marks': 89}, 'stu3': {'Name': 'harsh', 'Age': 13, 'Marks': 89}}
#         stu1   stu2   stu3
# Name   harsh  harsh  harsh
# Age       13     13     13
# Marks     89     89     89

# %%
#dictionary of list
var = {
    "Name" : ['harsh', 'dee', 'Singh'],
    "marks" : [1,2,3],
    "Age" : [1,2,3]
}
rf = pd.DataFrame(var)
rf['marks']+=100
relation = rf[['marks','Age']].corr()
relation
# Out:
#        marks  Age
# marks    1.0  1.0
# Age      1.0  1.0

# %%
#using only list of lists
var = [
     ['harsh', 'dee', 'Singh'],
     [1,2,3],
    [1,2,3]]
rf = pd.DataFrame(var, columns=['col1','col2','col3'])
rf[]
# Out:
#     col1 col2   col3
# 0  harsh  dee  Singh
# 1      1    2      3
# 2      1    2      3

# %%
#concatination
