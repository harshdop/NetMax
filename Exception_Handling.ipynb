# %%
try:
    print('hello')
    print(ss)
    print('bye')
    
except Exception as err:
    print(err)
    
finally:
    print("over")

#use of finally is cleanup
# like closing the connection after use
# closing the txt file after use
# Out:
# hello
# name 'ss' is not defined
# over

# %%
#else in except block
try:
    print('hello')
    # print(ss)
    print('bye')
    
except Exception as err:  # the else and finally block are optional;
                          # else will only run if error block does not run
                          # the else part can have its own try-except block
                          # else allows nested try-excpet block, it allows code generation into parts  
    print(err)
else:
    print("hii")
    
finally:
    print("over")



#use of finally is cleanup
# like closing the connection after use
# closing the txt file after use
# Out:
# hello
# bye
# hii
# over
