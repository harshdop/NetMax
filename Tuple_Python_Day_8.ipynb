# %%
'''
Immutable : A data which cannot be updated or changed once it has been created
Mutable : A data type in which data can be updated after it has been created
'''
'''
Tuple is an immutable data type in python
-> Follows continuous memory allocation;
-> zero (0) indexed
-> intialized by parenthesis ()
name_tuple = ()

->allows duplicate values

'''

# %%
'''
Tuple has only 3 inbuilt functions 
1. index
2. count
3. copy
max(), min(), len() 
'''

# %%
a = (1, 2, 3)
b = list(a)
print(type(b))
print(b)
# Out:
# <class 'list'>
# [1, 2, 3]

# %%
#initialization and declaration
t = (1,3,'d')
print(type(t))

#in python the defaule type in below situation in tuple
t1=23,5,3,33
print(type(t1))

#another way
t2=tuple(t)
print(type(t2))
print(t)
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# (1, 3, 'd')

# %%
t[0]=3
t.clear()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t[0]=3
#       2 t.clear()
#
# TypeError: 'tuple' object does not support item assignment

# %%
del t #del function still works

# %%
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(t)
#
# NameError: name 't' is not defined

# %%
print(t1.index('35'))
# Out:
# 3

# %%
print(t1.count(23))
# Out:
# 1

# %%
print(max(t1))
# Out:
# 33
